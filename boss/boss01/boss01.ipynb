# %% [markdown]
# # BOSS - Mundo 1

# %% [markdown]
# ##### O objetivo é unificar os dados em um único DataFrame e realizar uma série de operações de limpeza e filtragem para garantir a integridade do conjunto de dados.

# %% [markdown]
# ---

# %%
import pandas as pd

# %%
df = pd.read_csv('pokedex_(Update_05.20).csv')

# %% [markdown]
# ***Remoção de duplicatas: Verifique a existência de registros duplicados no DataFrame consolidado e elimine-os para garantir a unicidade dos dados.***

# %%
df_unique = df.drop_duplicates()
df_unique
# Out:
#       Unnamed: 0  pokedex_number                            name german_name  \
# 0              0               1                       Bulbasaur     Bisasam
# 1              1               2                         Ivysaur   Bisaknosp
# 2              2               3                        Venusaur    Bisaflor
# 3              3               3                   Mega Venusaur    Bisaflor
# 4              4               4                      Charmander    Glumanda
# ...          ...             ...                             ...         ...
# 1023        1023             888     Zacian Hero of Many Battles         NaN
# 1024        1024             889        Zamazenta Crowned Shield         NaN
# 1025        1025             889  Zamazenta Hero of Many Battles         NaN
# 1026        1026             890                       Eternatus         NaN
# 1027        1027             890             Eternatus Eternamax         NaN
#
# ...

# %% [markdown]
# ***Remover colunas irrelevantes: Analise as colunas presentes e exclua aquelas que não são relevantes para a análise***

# %%
relevant_columns = ['name', 'status', 'type_1', 'type_2', 'total_points', 'hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed']
df_cleaned = df_unique[relevant_columns]

df_cleaned
# Out:
#                                 name     status    type_1  type_2  \
# 0                          Bulbasaur     Normal     Grass  Poison
# 1                            Ivysaur     Normal     Grass  Poison
# 2                           Venusaur     Normal     Grass  Poison
# 3                      Mega Venusaur     Normal     Grass  Poison
# 4                         Charmander     Normal      Fire     NaN
# ...                              ...        ...       ...     ...
# 1023     Zacian Hero of Many Battles  Legendary     Fairy     NaN
# 1024        Zamazenta Crowned Shield  Legendary  Fighting   Steel
# 1025  Zamazenta Hero of Many Battles  Legendary  Fighting     NaN
# 1026                       Eternatus  Legendary    Poison  Dragon
# 1027             Eternatus Eternamax  Legendary    Poison  Dragon
#
#       total_points     hp  attack  defense  sp_attack  sp_defense  speed
# 0            318.0   45.0    49.0     49.0       65.0        65.0   45.0
# ...

# %% [markdown]
# ***Tratar valores ausentes: Identifique valores nulos ou ausentes e aplique as ações necessárias para corrigi-los (preenchimento ou remoção).***

# %%
df_filled = df_cleaned.ffill()
df_filled
# Out:
#                                 name     status    type_1  type_2  \
# 0                          Bulbasaur     Normal     Grass  Poison
# 1                            Ivysaur     Normal     Grass  Poison
# 2                           Venusaur     Normal     Grass  Poison
# 3                      Mega Venusaur     Normal     Grass  Poison
# 4                         Charmander     Normal      Fire  Poison
# ...                              ...        ...       ...     ...
# 1023     Zacian Hero of Many Battles  Legendary     Fairy   Steel
# 1024        Zamazenta Crowned Shield  Legendary  Fighting   Steel
# 1025  Zamazenta Hero of Many Battles  Legendary  Fighting   Steel
# 1026                       Eternatus  Legendary    Poison  Dragon
# 1027             Eternatus Eternamax  Legendary    Poison  Dragon
#
#       total_points     hp  attack  defense  sp_attack  sp_defense  speed
# 0            318.0   45.0    49.0     49.0       65.0        65.0   45.0
# ...

# %% [markdown]
# ***Filtrar Pokémon proibidos: Exclua do conjunto de dados todos os Pokémon que pertencem às seguintes categorias:***
# * Lendários e Sub-lendários
# * Míticos
# * Pokémon com MegaEvoluções

# %%
df_filtered = df_filled[(~df_filled['status'].isin(['Legendary', 'Sub Legendary', 'Mythical', 'Mega']))]
df_filtered
# Out:
#                name  status  type_1  type_2  total_points    hp  attack  \
# 0         Bulbasaur  Normal   Grass  Poison         318.0  45.0    49.0
# 1           Ivysaur  Normal   Grass  Poison         405.0  60.0    62.0
# 2          Venusaur  Normal   Grass  Poison         525.0  80.0    82.0
# 3     Mega Venusaur  Normal   Grass  Poison         625.0  80.0   100.0
# 4        Charmander  Normal    Fire  Poison         309.0  39.0    52.0
# ...             ...     ...     ...     ...           ...   ...     ...
# 1017      Arctovish  Normal   Water     Ice         505.0  90.0    90.0
# 1018      Duraludon  Normal   Steel  Dragon         535.0  70.0    95.0
# 1019         Dreepy  Normal  Dragon   Ghost         270.0  28.0    60.0
# 1020       Drakloak  Normal  Dragon   Ghost         410.0  68.0    80.0
# 1021      Dragapult  Normal  Dragon   Ghost         600.0  88.0   120.0
#
#       defense  sp_attack  sp_defense  speed
# 0        49.0       65.0        65.0   45.0
# ...
