# %% [markdown]
# # Exercício 22

# %% [markdown]
# ***Normalize o atributo Rendimentos utilizando Re-escala [0,1].***

# %% [markdown]
# ![image.png](attachment:7c732ce4-f279-46f0-b4a1-afc8bc0e62fb.png)

# %% [markdown]
# ***Encontre o menor e o maior valor do atributo e atribui os valores extremos da nova escala.***

# %% [markdown]
# ![image.png](attachment:ac9aedcb-af8c-456c-b83e-506f469c041b.png)

# %% [markdown]
# ***Normalize os seguintes valores***
# * Re-escala [0,1] e padronização N(0,1)

# %% [markdown]
# ![image.png](attachment:c5700ad3-bfc6-4297-8e52-a5b09897c461.png)
